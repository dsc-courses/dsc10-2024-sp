# %%
import os

def write_markdown_file(line):
    # Split the line by tab to get individual fields
    fields = line.strip().split('\t')
    
    # Extract information from fields
    timestamp, full_name, pronouns, _, description, hometown, askabout, food = fields
    first_name, last_name = full_name.split()
    
    # Format the markdown content
    # Need to manually change the food emoji later
    content = f"""---
name: {full_name}
role: Tutor
pronouns: {pronouns}
email: 
photo: assets/staff-images/sp24/{last_name.lower()}-{first_name.lower()}.jpg
description: {description}
hometown: {hometown}
askabout: {askabout}
foodemoji: 🍛 
food: {food}
---"""
    
    path = "../_staffers/"

    # Define the file name
    file_name = f"{path}{last_name.lower()}-{first_name.lower()}.md"
    
    # Write the content to the file
    with open(file_name, 'w') as f:
        f.write(content)
    
    print(f"{file_name} has been written successfully!")

# %%
# Copy-paste the eight relevant columns from the staff onboarding form responses
all_lines = """3/22/2024 22:03:53	Jason Huynh	he/him	https://drive.google.com/file/d/106jM7_GJ_JYm_G2-i5Y7iiV56CfkkAcB/view?usp=sharing	2nd year, Data Science, Sixth	Modesto, CA	Gym, music, video games	🍝 Catania, Tacos El Gordo, Pho Cow Cali Express
3/23/2024 6:39:08	Cici Xu	she/her	https://drive.google.com/file/d/1vlwXr1SzpOnw6DJB7E2nlScMiEEbO0Qp/view?usp=drive_link	3rd year, Data Science and Math-Econ, Sixth	Shanghai, China	Hiking, swimming, food 	🍜 Shancheng Lameizi Hot Pot, Phill's BBQ
3/23/2024 12:28:14	Kate Feng	she/her	https://drive.google.com/file/d/1mxx36mI_uuCd1momzQEdtBwRXveeCvFS/view?usp=sharing	1st year, Data Science, Seventh	San Jose, CA	Content creation, taekwondo, Ghibli movies	🥐 La Clochette, Formoosa, YinTang
3/23/2024 12:43:14	Athulith Paraselli	he/him	https://drive.google.com/file/d/1Qv6mOHmhxc-OiCUIJgz-LAdCm6IxqtC_/view?usp=drivesdk	3rd year, Math-CS, Data Science Minor, Marshall	San Diego, CA	Music, video games, running	🍗 Raising Canes, CoCo Ichibanya, Chipotle
3/23/2024 16:30:43	Ashley Ho	she/her	https://drive.google.com/file/d/1axBMlAyfSICSAP0nZZtjnPi6-aEkZ0in/view?usp=sharing	4th year, Probability & Statistics, Marshall	Irvine, CA	Cooking, movies/TV shows, corgis	🥟 Tasty Noodle House, Monello, Pho La Jolla
3/23/2024 20:49:23	Claire Wang	she/her	https://drive.google.com/file/d/1K5mg4mE6ytpYYhK4MDDTBLcfjK7Y1A0Y/view?usp=sharing	1st year, Data Science, Seventh	San Jose, CA	Clarinet, piano, books	🌮 Taco stand, Mendocino Farms
3/24/2024 2:05:28	Yutian Shi	she/her	https://drive.google.com/file/d/1_6Wf7I7fNSvT3F7FqZGLze1g1ZkOtSNC/view?usp=share_link	4th year, Data Science, Sixth	Beijing, China	Traditional Chinese art, photography, food	🍦 Yogurt World, Regents Pizzeria, BenGong's Tea
3/24/2024 2:40:09	Oren Ciolli	he/him	https://drive.google.com/file/d/10KWQ5rUMgfQT_L-Af4452BST5o97dflb/view?usp=drive_link	4th year, Data Science and Math-Econ, Revelle	San Jose, CA	Basketball, music, cooking	🍜 Raki Raki, Turmeric Thai Kitchen, Shan Xi Magic Kitchen
3/24/2024 22:31:09	Pallavi Prabhu	she/her	https://drive.google.com/file/d/1ohZshbfRa9V2A-tACoXrtSYaCTc-oWX6/view?usp=share_link	3rd year, Data Science, Marshall	Cypress, CA	Painting, sculpting, baking, TV shows	🧇 SomiSomi, Silverlake Ramen
3/25/2024 11:27:50	Sofia Tkachenko	she/her	https://drive.google.com/file/d/12_B5BDtQCgSzToeFfoygW_WedO_cx5sn/view?usp=drivesdk	2nd year, Applied Math, Muir	San Jose, CA	Hiking, hot tubs, sweet treats	🧋 Tasty Noodle House, Tofu House, BenGong’s Tea
3/22/2024 20:19:58	Aaron Rasin	he/him	https://drive.google.com/file/d/1pZSLFL9gGeMK-ND-z5FhDcMI81me3VPw/view?usp=sharing	4th year, Linguistics, Seventh	Boston, MA	La Jolla Symphony, Linguistics at UCSD, NLP	🍣 Sushi Tadokoro, Main Chick, Taco Stand
3/22/2024 21:15:29	Minchan Kim	he/him	https://drive.google.com/file/d/1euPRK57DMQWbURWkitbomL7Rn8My8Iqn/view?usp=sharing	2nd year, Data Science, Revelle	Pyeongtaek, South Korea	NBA, F1, swimming, tennis	🍗 Wingstop, Canes, Chipotle
3/22/2024 22:11:01	Sophie Wang	she/her	https://docs.google.com/document/d/1JrYLMl5SnxqZ_DYmmnUTYlUXnWLLNy243v37cc8pMEU/edit?usp=sharing	2nd year, Data Science, Marshall	Zhejiang, China	Films, painting, restaurants in San Diego	🍲 Din Tai Fung, YinTang, BenGong's Tea
3/23/2024 15:12:37	Pranav Rajaram	he/him	https://drive.google.com/file/d/1_A2ja6xNUg_9-Dz2ehCl7njsZ4aQ82Rg/view?usp=sharing	1st year, Data Science, Marshall	Westford, MA	Football, poker, Drake	🥪 The Melt, Taco Stand, SomiSomi
3/23/2024 16:02:58	Daniel Budidharma	he/him	https://drive.google.com/file/d/1xwsVBFTvo6KaiobE2BEn9KSWhhn9SXnS/view?usp=sharing	1st year, Data Science, Sixth	Jakarta, Indonesia	Movies, manga/anime, Europa Universalis 4	🌶️ Spicy City, Jasmine, Tacos El Gordo, Taegukgi
3/23/2024 22:31:10	Norah Kerendian	she/her	https://drive.google.com/file/d/12qunEaotQ4Czbk3WPJNxJKWkud84HwnQ/view?usp=sharing	2nd year, Data Science, Marshall	Los Angeles, CA	Reading, networking, taekwondo	🥐 Parisien Gourmandises, La Mesa Pizzaworks
3/23/2024 22:47:22	Calvin Nguyen	he/him	https://drive.google.com/file/d/1zM9dpb4u2CBMSN8FUuc-T9DfIMT2Zmsw/view?usp=sharing	3rd Year, Data Science, Design Minor, Marshall	El Monte, California	Internships at Deloitte and Hey Social Good, research at SIO, competitive Mario Kart	🍜 Pho Hoa, North Italia, The Taco Stand, formoosa 
3/23/2024 23:16:10	Raine Hoang	they/them	https://drive.google.com/file/d/1-Lxj8yY1REXiJym1caTnncbCFYi4O5RR/view?usp=sharing	2nd year, Data Science, Sixth	Los Angeles, CA	Crochet, video games, art/drawing, wood carving	🍜 Ramen Nagi, Tofu House, SomiSomi
3/24/2024 0:16:50	Michelle Hong	she/her	https://drive.google.com/file/d/1lQYR70tVWKExJzX9J79EXnXd9f7f_xxJ/view?usp=sharing	1st year, Data Science, Seventh	Dublin, CA	Bass guitar, matcha, thrifting, track	🐠 Hawaiiian Fresh Poke, Pinkberry
3/25/2024 1:51:30	Ciro Zhang	he/him	https://drive.google.com/file/d/1sw0lE791jZmE3fRRtuHlT9a8ibpZ2pWi/view?usp=sharing	2nd year, Data Science and Computer Engineering, ERC	Richmond, BC, Canada	Chess, cockatiels, badminton	🌮 Chipotle, Shake Shack, Mains Hot Chicken
3/25/2024 12:26:08	Vivian Lin	she/her	https://drive.google.com/file/d/14uJ06sY3W2xoOva256fEfbrECGweFtaA/view?usp=drivesdk	4th year, Data Science, Warren 	San Jose, CA 	Traveling, pickleball, hot yoga  	🍣 Little Sakana, Cucina Enoteca, Wingstop, Hawaiian Fresh Seafood"""
lines = all_lines.split("\n")
for line in lines:
    write_markdown_file(line)
# Out:
# ../_staffers/huynh-jason.md has been written successfully!
# ../_staffers/xu-cici.md has been written successfully!
# ../_staffers/feng-kate.md has been written successfully!
# ../_staffers/paraselli-athulith.md has been written successfully!
# ../_staffers/ho-ashley.md has been written successfully!
# ../_staffers/wang-claire.md has been written successfully!
# ../_staffers/shi-yutian.md has been written successfully!
# ../_staffers/ciolli-oren.md has been written successfully!
# ../_staffers/prabhu-pallavi.md has been written successfully!
# ../_staffers/tkachenko-sofia.md has been written successfully!
# ../_staffers/rasin-aaron.md has been written successfully!
# ../_staffers/kim-minchan.md has been written successfully!
# ../_staffers/wang-sophie.md has been written successfully!
# ../_staffers/rajaram-pranav.md has been written successfully!
# ../_staffers/budidharma-daniel.md has been written successfully!
# ../_staffers/kerendian-norah.md has been written successfully!
# ...

# %%
import os
import re
import csv
import requests
from PIL import Image
from io import BytesIO

def download_and_save_images(csv_content, directory):
    # Create directory if it doesn't exist
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    # Parse the CSV content line by line
    reader = csv.reader(csv_content.splitlines())
    #next(reader)  # Skip the header row
    
    for row in reader:
        print(row)
        timestamp, full_name, pronouns, link = row[0].split("\t")
        first_name, last_name = full_name.split()
        
        # Format the file name
        file_name = f"{last_name.lower()}-{first_name.lower()}.jpg"
        file_path = os.path.join(directory, file_name)
        
        match = re.search(r'/d/([^/]+)/', link)
        if match:
            file_id = match.group(1)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        else:
            print(f"Failed to extract file ID from link for {full_name}. Skipping.")
            continue
        
        try:
            # Download the image using the modified download link
            response = requests.get(download_link)
            response.raise_for_status()
            
            # Open the image and convert it to JPEG if necessary
            img = Image.open(BytesIO(response.content))
            if img.format != 'JPEG':
                img = img.convert('RGB')
            
            # Save the image to the specified directory
            img.save(file_path, 'JPEG')
            print(f"Image for {full_name} has been saved successfully to {file_path}")
        
        except Exception as e:
            print(f"Failed to download and save image for {full_name}. Error: {e}")

# Copy-paste the first four columns from the staff onboarding form responses
csv_content = """3/22/2024 22:03:53	Jason Huynh	he/him	https://drive.google.com/file/d/106jM7_GJ_JYm_G2-i5Y7iiV56CfkkAcB/view?usp=sharing
3/23/2024 6:39:08	Cici Xu	she/her	https://drive.google.com/file/d/1vlwXr1SzpOnw6DJB7E2nlScMiEEbO0Qp/view?usp=drive_link
3/23/2024 12:28:14	Kate Feng	she/her	https://drive.google.com/file/d/1mxx36mI_uuCd1momzQEdtBwRXveeCvFS/view?usp=sharing
3/23/2024 12:43:14	Athulith Paraselli	he/him	https://drive.google.com/file/d/1Qv6mOHmhxc-OiCUIJgz-LAdCm6IxqtC_/view?usp=drivesdk
3/23/2024 16:30:43	Ashley Ho	she/her	https://drive.google.com/file/d/1axBMlAyfSICSAP0nZZtjnPi6-aEkZ0in/view?usp=sharing
3/23/2024 20:49:23	Claire Wang	she/her	https://drive.google.com/file/d/1K5mg4mE6ytpYYhK4MDDTBLcfjK7Y1A0Y/view?usp=sharing
3/24/2024 2:05:28	Yutian Shi	she/her	https://drive.google.com/file/d/1_6Wf7I7fNSvT3F7FqZGLze1g1ZkOtSNC/view?usp=share_link
3/24/2024 2:40:09	Oren Ciolli	he/him	https://drive.google.com/file/d/10KWQ5rUMgfQT_L-Af4452BST5o97dflb/view?usp=drive_link
3/24/2024 22:31:09	Pallavi Prabhu	she/her	https://drive.google.com/file/d/1ohZshbfRa9V2A-tACoXrtSYaCTc-oWX6/view?usp=share_link
3/25/2024 11:27:50	Sofia Tkachenko	she/her	https://drive.google.com/file/d/12_B5BDtQCgSzToeFfoygW_WedO_cx5sn/view?usp=drivesdk
3/22/2024 20:19:58	Aaron Rasin	he/him	https://drive.google.com/file/d/1pZSLFL9gGeMK-ND-z5FhDcMI81me3VPw/view?usp=sharing
3/22/2024 21:15:29	Minchan Kim	he/him	https://drive.google.com/file/d/1euPRK57DMQWbURWkitbomL7Rn8My8Iqn/view?usp=sharing
3/22/2024 22:11:01	Sophie Wang	she/her	https://docs.google.com/document/d/1JrYLMl5SnxqZ_DYmmnUTYlUXnWLLNy243v37cc8pMEU/edit?usp=sharing
3/23/2024 15:12:37	Pranav Rajaram	he/him	https://drive.google.com/file/d/1_A2ja6xNUg_9-Dz2ehCl7njsZ4aQ82Rg/view?usp=sharing
3/23/2024 16:02:58	Daniel Budidharma	he/him	https://drive.google.com/file/d/1xwsVBFTvo6KaiobE2BEn9KSWhhn9SXnS/view?usp=sharing
3/23/2024 22:31:10	Norah Kerendian	she/her	https://drive.google.com/file/d/12qunEaotQ4Czbk3WPJNxJKWkud84HwnQ/view?usp=sharing
3/23/2024 22:47:22	Calvin Nguyen	he/him	https://drive.google.com/file/d/1zM9dpb4u2CBMSN8FUuc-T9DfIMT2Zmsw/view?usp=sharing
3/23/2024 23:16:10	Raine Hoang	they/them	https://drive.google.com/file/d/1-Lxj8yY1REXiJym1caTnncbCFYi4O5RR/view?usp=sharing
3/24/2024 0:16:50	Michelle Hong	she/her	https://drive.google.com/file/d/1lQYR70tVWKExJzX9J79EXnXd9f7f_xxJ/view?usp=sharing
3/25/2024 1:51:30	Ciro Zhang	he/him	https://drive.google.com/file/d/1sw0lE791jZmE3fRRtuHlT9a8ibpZ2pWi/view?usp=sharing
3/25/2024 12:26:08	Vivian Lin	she/her	https://drive.google.com/file/d/14uJ06sY3W2xoOva256fEfbrECGweFtaA/view?usp=drivesdk"""

# The directory where the images should be saved
directory = "../assets/staff-images/sp24"

# Call the function with the CSV content and the directory
download_and_save_images(csv_content, directory)

# This will extract some, others will need to be done manually.
# Out:
# ['3/22/2024 22:03:53\tJason Huynh\the/him\thttps://drive.google.com/file/d/106jM7_GJ_JYm_G2-i5Y7iiV56CfkkAcB/view?usp=sharing']
# Image for Jason Huynh has been saved successfully to ../assets/staff-images/sp24\huynh-jason.jpg
# ['3/23/2024 6:39:08\tCici Xu\tshe/her\thttps://drive.google.com/file/d/1vlwXr1SzpOnw6DJB7E2nlScMiEEbO0Qp/view?usp=drive_link']
# Image for Cici Xu has been saved successfully to ../assets/staff-images/sp24\xu-cici.jpg
# ['3/23/2024 12:28:14\tKate Feng\tshe/her\thttps://drive.google.com/file/d/1mxx36mI_uuCd1momzQEdtBwRXveeCvFS/view?usp=sharing']
# Failed to download and save image for Kate Feng. Error: cannot identify image file <_io.BytesIO object at 0x000001C6707F8090>
# ['3/23/2024 12:43:14\tAthulith Paraselli\the/him\thttps://drive.google.com/file/d/1Qv6mOHmhxc-OiCUIJgz-LAdCm6IxqtC_/view?usp=drivesdk']
# Failed to download and save image for Athulith Paraselli. Error: cannot identify image file <_io.BytesIO object at 0x000001C66EDA1400>
# ...
